# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv("C:/SOOKTAT/0. 프로젝트/Taxi/data/train_fin.csv", nrows=500_000)
train_df = train_df.drop(columns = ['Unnamed: 0', 'key', 'pickup_datetime'])

train_df
# Out:
#         fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0               4.5        -73.844311        40.721319         -73.841610
# 1              16.9        -74.016048        40.711303         -73.979268
# 2               5.7        -73.982738        40.761270         -73.991242
# 3               7.7        -73.987130        40.733143         -73.991567
# 4               5.3        -73.968095        40.768008         -73.956655
# ...             ...               ...              ...                ...
# 499995         13.7        -73.978837        40.777262         -74.008987
# 499996          4.9        -73.978337        40.751873         -73.978581
# 499997          6.5        -73.966573        40.764767         -73.952655
# 499998          7.7        -73.971600        40.781890         -73.971600
# 499999         14.0        -73.870905        40.773717         -73.933850
#
#         dropoff_latitude  passenger_count  Year  Month  Date  Day of Week  \
# ...

# %%
train_df = train_df.drop(columns = ['fare_amount_ontaxi'])

train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   fare_amount        500000 non-null  float64
#  1   pickup_longitude   500000 non-null  float64
#  2   pickup_latitude    500000 non-null  float64
#  3   dropoff_longitude  500000 non-null  float64
#  4   dropoff_latitude   500000 non-null  float64
#  5   passenger_count    500000 non-null  int64
#  6   Year               500000 non-null  int64
#  7   Month              500000 non-null  int64
#  8   Date               500000 non-null  int64
#  9   Day of Week        500000 non-null  int64
#  10  Hour               500000 non-null  int64
#  11  taxi_amount        500000 non-null  int64
# dtypes: float64(5), int64(7)
# memory usage: 45.8 MB

# %% [markdown]
# * xgboost

# %%
from xgboost import XGBClassifier
from xgboost import plot_importance
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, f1_score, roc_auc_score
import warnings
warnings.filterwarnings('ignore')

# %%
X = train_df.drop(columns = ['fare_amount', 'pickup_longitude', 'pickup_latitude',
                            'dropoff_longitude', 'dropoff_latitude', 'passenger_count'])
y = train_df['fare_amount']

train_X, valid_X, train_y, valid_y = train_test_split(X, y, test_size = 0.4, random_state = 1)

# %%
xgb = XGBClassifier(n_estimators = 500, learning_rate = 0.1, max_depth = 100, eval_metric='logloss')
xgb.fit(train_X, train_y)
xgb_pred = xgb.predict(test_X)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-e72f3d098452> in <module>
#       1 xgb = XGBClassifier(n_estimators = 500, learning_rate = 0.1, max_depth = 100, eval_metric='logloss')
# ----> 2 xgb.fit(train_X, train_y)
#       3 xgb_pred = xgb.predict(test_X)
#
# ~\anaconda3\lib\site-packages\xgboost\core.py in inner_f(*args, **kwargs)
#     504         for k, arg in zip(sig.parameters, args):
#     505             kwargs[k] = arg
# --> 506         return f(**kwargs)
#     507
#     508     return inner_f
#
# ~\anaconda3\lib\site-packages\xgboost\sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1248         )
#    1249
# -> 1250         self._Booster = train(
#    1251             params,
# ...

# %%
import xgboost

xgb_model = xgboost.XGBRegressor(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75,
                           colsample_bytree=1, max_depth=7)

xgb_model.fit(train_X, train_y)
xgb_pred = xgb_model.predict(valid_X)

# %%
from sklearn.ensemble import RandomForestClassifier

rf_clf = RandomForestClassifier()

rf_clf.fit(train_X, train_y)

print(rf_clf.score(train_X, train_y)) #

print(rf_clf.score(valid_X, valid_y)) #1.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-530cd5b351af> in <module>
#       3 rf_clf = RandomForestClassifier()
#       4
# ----> 5 rf_clf.fit(train_X, train_y)
#       6
#       7 print(rf_clf.score(train_X, train_y)) #
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     329         self.n_outputs_ = y.shape[1]
#     330
# --> 331         y, expanded_class_weight = self._validate_y_class_weight(y)
#     332
#     333         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _validate_y_class_weight(self, y)
#     557
#     558     def _validate_y_class_weight(self, y):
# --> 559         check_classification_targets(y)
#     560
#     561         y = np.copy(y)
#
# ...

# %%
from sklearn import svm

clf = svm.SVC(kernel='linear')
clf.fit(train_X, train_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-2ab1f4dae00f> in <module>
#       2
#       3 clf = svm.SVC(kernel='linear')
# ----> 4 clf.fit(train_X, train_y)
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     171                                        accept_large_sparse=False)
#     172
# --> 173         y = self._validate_targets(y)
#     174
#     175         sample_weight = np.asarray([]
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in _validate_targets(self, y)
#     551     def _validate_targets(self, y):
#     552         y_ = column_or_1d(y, warn=True)
# --> 553         check_classification_targets(y)
#     554         cls, y = np.unique(y_, return_inverse=True)
#     555         self.class_weight_ = compute_class_weight(self.class_weight,
#
# ...

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb_clf = GradientBoostingClassifier(random_state=0)
gb_clf.fit(train_X, train_y)
gb_pred = gb_clf.predict(test_X)
gb.accuracy = accuracy_score(test_y, gb_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-586e2b8a759c> in <module>
#       2
#       3 gb_clf = GradientBoostingClassifier(random_state=0)
# ----> 4 gb_clf.fit(train_X, train_y)
#       5 gb_pred = gb_clf.predict(test_X)
#       6 gb.accuracy = accuracy_score(test_y, gb_pred)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py in fit(self, X, y, sample_weight, monitor)
#     421
#     422         if is_classifier(self):
# --> 423             y = self._validate_y(y, sample_weight)
#     424         else:
#     425             y = self._validate_y(y)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py in _validate_y(self, y, sample_weight)
#    1101
#    1102     def _validate_y(self, y, sample_weight):
# -> 1103         check_classification_targets(y)
#    1104         self.classes_, y = np.unique(y, return_inverse=True)
# ...
